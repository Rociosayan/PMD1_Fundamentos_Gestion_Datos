# %% [markdown]
# # LABORATORIO N° 14 - Gobierno de Datos y Roles
# ## FUNDAMENTOS DE GESTIÓN DE DATOS - Semana 14
#
# **Docente:** Pilar Rocío Sayán Mejía
# **Semestre:** 2026-I
#
# ---

# %% [markdown]
# ## ACTIVIDAD 1: Revisión de Conceptos - Gobierno de Datos
#
# Complete la siguiente tabla con sus definiciones:

# %% [markdown]
# | Concepto | Definición con sus propias palabras |
# |----------|-------------------------------------|
# | 1. ¿Qué es el gobierno de datos y cuál es su objetivo? | |
# | 2. Marco DAMA-DMBOK: áreas de conocimiento | |
# | 3. Rol de Data Owner: responsabilidades | |
# | 4. Rol de Data Steward: responsabilidades | |
# | 5. Rol de Data Engineer: responsabilidades | |
# | 6. Rol de Data Scientist: responsabilidades | |
# | 7. Rol de Data Analyst: responsabilidades | |
# | 8. Políticas de privacidad: GDPR | |
# | 9. Ley 29733 (Perú): protección de datos personales | |
# | 10. Importancia del portafolio profesional en datos | |

# %% [markdown]
# ## ACTIVIDAD 2: Investigación de Roles en el Mercado Laboral
#
# ### Paso 1: Selección del rol de interés

# %% [markdown]
# **ROLES DISPONIBLES:**
# - **Data Analyst**: Análisis de datos y visualización
# - **Data Engineer**: Construcción de pipelines de datos
# - **Data Scientist**: Modelado predictivo y ML
# - **Data Steward**: Gobierno y calidad de datos
# - **BI Analyst**: Inteligencia de negocios

# %% [markdown]
# **Pregunta 1:** ¿Qué rol de datos te interesa más y por qué?
#
# **Respuesta:**

# %% [markdown]
# ### Paso 2: Investigación de ofertas laborales
#
# Busca al menos 3 ofertas laborales reales para el rol seleccionado en LinkedIn, Bumeran o Computrabajo.

# %%
import pandas as pd

# Completa con la información de las ofertas encontradas
ofertas = {
    'Oferta': ['1', '2', '3'],
    'Empresa': ['', '', ''],
    'Plataforma': ['', '', ''],
    'Puesto': ['', '', ''],
    'Competencia_1': ['', '', ''],
    'Competencia_2': ['', '', ''],
    'Competencia_3': ['', '', ''],
    'Competencia_4': ['', '', ''],
    'Competencia_5': ['', '', '']
}

df_ofertas = pd.DataFrame(ofertas)
df_ofertas

# %%
# Resumen de competencias más pedidas
print("COMPETENCIAS MÁS PEDIDAS EN LAS OFERTAS:")
print("="*50)

# Edita esta lista con las competencias que más se repiten
competencias_frecuentes = [
    "1. _____________________________",
    "2. _____________________________",
    "3. _____________________________",
    "4. _____________________________",
    "5. _____________________________"
]

for c in competencias_frecuentes:
    print(c)

# %% [markdown]
# **Pregunta 2:** ¿Cuántas de estas competencias ya tienes? ¿Cuáles necesitas desarrollar?
#
# **Respuesta:**

# %% [markdown]
# ---
# ## ACTIVIDAD 3: Construcción del Portafolio Profesional
#
# ### Paso 1: Organización del repositorio grupal en GitHub

# %% [markdown]
# #### Estructura recomendada del repositorio:
#
# ```
# proyecto-fgd-2026/
# ├── README.md            # Descripción profesional del proyecto
# ├── data/
# │   ├── raw/              # Datos originales
# │   └── processed/        # Datos procesados
# ├── notebooks/
# │   ├── 01_eda.ipynb      # Análisis exploratorio
# │   ├── 02_limpieza.ipynb # Limpieza de datos
# │   ├── 03_modelo.ipynb   # Modelo de ML
# │   └── 04_calidad.ipynb  # Análisis de calidad
# ├── sql/
# │   └── queries.sql       # Consultas principales
# ├── images/               # Gráficos y diagramas
# └── requirements.txt      # Dependencias
# ```

# %% [markdown]
# ### Paso 2: Plantilla de README profesional

# %%
# Plantilla de README.md - Copia y edita en tu repositorio

readme_template = '''
# 📊 Nombre del Proyecto

## 📝 Descripción
Breve descripción del problema de negocio y la solución implementada.

## 🛠️ Tecnologías utilizadas
- Python 3.x
- Pandas
- SQLite
- Scikit-learn
- Matplotlib / Seaborn

## 👥 Integrantes del equipo
| Nombre | Rol en el proyecto |
|--------|-------------------|
| Integrante 1 | Descripción |
| Integrante 2 | Descripción |

## 📁 Estructura del repositorio
Ver documentación en cada carpeta.

## 📈 Resultados principales
- Hallazgo 1
- Hallazgo 2
- Métricas del modelo

## 🚀 Cómo ejecutar
1. Clonar repositorio
2. Instalar dependencias: `pip install -r requirements.txt`
3. Ejecutar notebooks en orden

## 📸 Capturas
Insertar imágenes de gráficos principales.
'''

print(readme_template)

# %% [markdown]
# ### Paso 3: Verificación del perfil de LinkedIn

# %% [markdown]
# #### Checklist para tu perfil de LinkedIn:
#
# - [ ] **Foto profesional** (fondo neutro, buena iluminación)
# - [ ] **Banner** relacionado a datos/tecnología
# - [ ] **Headline** con tu rol de interés
#   - Ejemplo: "Aspiring Data Analyst | Python | SQL | Machine Learning"
# - [ ] **Sección About** con tu historia profesional
# - [ ] **Experiencia** actualizada
# - [ ] **Proyectos** con el proyecto del curso
# - [ ] **Skills** técnicas: Python, SQL, Pandas, Machine Learning, Data Visualization
# - [ ] **Certificaciones** (Kaggle, Coursera, etc.)

# %%
# Ejemplo de Headline efectivo para LinkedIn
print("EJEMPLOS DE HEADLINES PARA PERFILES DE DATOS:")
print("="*50)

headlines = [
    "Data Analyst | Python | SQL | Tableau | Transformando datos en decisiones",
    "Aspiring Data Scientist | Machine Learning | Python | Buscando oportunidades",
    "Data Engineer | ETL | SQL | Python | Cloud | Construyendo pipelines de datos",
    "BI Analyst | Power BI | SQL | Data Visualization | Insights que impulsan negocios"
]

for h in headlines:
    print(f"\n→ {h}")

# %% [markdown]
# ---
# ## PREGUNTAS FINALES
#
# **Pregunta A:** ¿Qué rol de datos te interesa más y por qué? Menciona las competencias que ya tienes.
#
# **Respuesta:**

# %% [markdown]
# **Pregunta B:** Pega el enlace de tu repositorio de GitHub.
#
# **Respuesta:**

# %% [markdown]
# **Pregunta C:** Pega el enlace de tu perfil de LinkedIn actualizado.
#
# **Respuesta:**

# %% [markdown]
# **Pregunta D:** ¿Qué badges o certificaciones adicionales planeas obtener?
#
# **Respuesta:**

# %% [markdown]
# ---
# ## CONCLUSIONES
#
# Escriba las conclusiones técnicas y de aprendizaje obtenidas tras la práctica:
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ---
# ## RECURSOS ADICIONALES
#
# ### Certificaciones recomendadas:
# - **Kaggle**: Free micro-courses y certifications
# - **Google Data Analytics Certificate**
# - **IBM Data Science Professional Certificate**
# - **Microsoft Azure Data Fundamentals**
#
# ### Plataformas para practicar:
# - Kaggle: https://www.kaggle.com/
# - LeetCode (SQL): https://leetcode.com/problemset/database/
# - HackerRank: https://www.hackerrank.com/domains/sql
# - DataCamp: https://www.datacamp.com/
